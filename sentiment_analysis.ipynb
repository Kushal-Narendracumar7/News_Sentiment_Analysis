# %%
from data_collection import collect_news_data
from model import analyze_sentiment
import pandas as pd
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3672 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from data_collection import collect_news_data
#
#   File c:\Users\Lenovo\Desktop\News_Sentiment_Analysis\data_collection.py:25
#     'apiKey':os.getenv('NEWS_KEY')
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def get_sentiments(df):
    df['text_to_analyze'] = df['text_to_analyze'].fillna('').astype(str)
    df['sentiments'] = df['text_to_analyze'].apply(lambda x : analyze_sentiment(x)[0]['label'])
    return df
