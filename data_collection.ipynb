# %%
import pandas as pd 
import requests
from datetime import datetime,timedelta
import os

# %%
def collect_news_data(keywords,days):
    API_URL = "https://newsapi.org/v2/everything"

    params = {
        'q' : keywords,
        'language':'en',
        'from' : (datetime.now() - timedelta(days = days)).strftime('%Y-%m-%d'),
        'to' : datetime.now().strftime('%Y-%m-%d'),
        'sortBy':'popularity',
        'apiKey':os.getenv('NEWS_KEY')
    }

    response = requests.get(API_URL,params = params)
    data = response.json()
    news_df = pd.DataFrame(data['articles'])
    news_df = news_df[['title','description','content','url']]
    news_df['text_to_analyze'] = news_df['title'] + ' ' + news_df['description'] + ' ' + news_df['content']
    return news_df

# %%
API_URL = "https://newsapi.org/v2/everything"

params = {
        'q' : "IPL",
        'language':'en',
        'from' : (datetime.now() - timedelta(days = 4)).strftime('%Y-%m-%d'),
        'to' : datetime.now().strftime('%Y-%m-%d'),
        'sortBy':'popularity',
        'apiKey':os.getenv('NEWS_KEY')
    }

response = requests.get(API_URL,params = params)
data = response.json()
news_df = pd.DataFrame(data['articles'])
news_df = news_df[['title','description','content','url']]
news_df.head()
# Out:
#                                                title  \
# 0  PBKS vs GT IPL 2026 Live Cricket Streaming Onl...
# 1  MS Dhoni ruled out for first two weeks of IPL ...
# 2  ‘This win, we dedicate to the 11 fans who we l...
# 3  ‘Mahi usually doesn’t do this’: R Ashwin on MS...
# 4  ‘Please don’t create any stories’: Why Suryaku...
#
#                                          description  \
# 0  IPL 2026 PBKS vs GT Live Cricket Score Streami...
# 1  IPL 2026: CSK talisman MS Dhoni has been ruled...
# 2  The fans died in a stampede last June near the...
# 3  IPL 2026: With Dhoni out injured, India wicket...
# 4  IPL 2026: Suryakumar Yadav walked out to bat a...
#
#                                              content  \
# 0  IPL 2026 PBKS vs GT Live Cricket Score Streami...
# 1  Chennai Super Kings talisman MS Dhoni has suff...
# 2  Royal Challengers Bengaluru captain Rajat Pati...
# 3  With an injury grappling him ahead of Chennai ...
# 4  One of the early talking points about the Mumb...
#
#                                                  url
# 0  https://indianexpress.com/article/sports/crick...
# 1  https://indianexpress.com/article/sports/crick...
# 2  https://indianexpress.com/article/sports/crick...
# 3  https://indianexpress.com/article/sports/crick...
# 4  https://indianexpress.com/article/sports/crick...
